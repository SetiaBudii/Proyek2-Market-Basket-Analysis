# %% [markdown]
# ## <b>Pengujian Performance antara Apriori dan FPGrowth

# %% [markdown]
# ### Import Library

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import fpgrowth
import time

# %% [markdown]
# ### <b>Read Datasets

# %%
data = pd.read_csv("../datasets/ind.csv", sep = ";")
data.head(20)
# Out:
# C:\Users\Budi\AppData\Local\Temp\ipykernel_196\1475147716.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../datasets/ind.csv", sep = ";")
#     BillNo                             Itemname  Quantity              Date  \
# 0   536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1   536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2   536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3   536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4   536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
# 5   536365         SET 7 BABUSHKA NESTING BOXES         2  01.12.2010 08:26
# 6   536365    GLASS STAR FROSTED T-LIGHT HOLDER         6  01.12.2010 08:26
# 7   536366               HAND WARMER UNION JACK         6  01.12.2010 08:28
# 8   536366            HAND WARMER RED POLKA DOT         6  01.12.2010 08:28
# 9   536367        ASSORTED COLOUR BIRD ORNAMENT        32  01.12.2010 08:34
# 10  536367            POPPY'S PLAYHOUSE BEDROOM         6  01.12.2010 08:34
# 11  536367            POPPY'S PLAYHOUSE KITCHEN         6  01.12.2010 08:34
# 12  536367    FELTCRAFT PRINCESS CHARLOTTE DOLL         8  01.12.2010 08:34
# 13  536367               IVORY KNITTED MUG COSY         6  01.12.2010 08:34
# 14  536367   BOX OF 6 ASSORTED COLOUR TEASPOONS         6  01.12.2010 08:34
# 15  536367         BOX OF VINTAGE JIGSAW BLOCKS         3  01.12.2010 08:34
# 16  536367       BOX OF VINTAGE ALPHABET BLOCKS         2  01.12.2010 08:34
# 17  536367             HOME BUILDING BLOCK WORD         3  01.12.2010 08:34
# 18  536367             LOVE BUILDING BLOCK WORD         3  01.12.2010 08:34
# 19  536367          RECIPE BOX WITH METAL HEART         4  01.12.2010 08:34
#
#    Price  CustomerID         Country
# 0   2,55     17850.0  United Kingdom
# 1   3,39     17850.0  United Kingdom
# 2   2,75     17850.0  United Kingdom
# 3   3,39     17850.0  United Kingdom
# 4   3,39     17850.0  United Kingdom
# 5   7,65     17850.0  United Kingdom
# 6   4,25     17850.0  United Kingdom
# 7   1,85     17850.0  United Kingdom
# 8   1,85     17850.0  United Kingdom
# 9   1,69     13047.0  United Kingdom
# 10   2,1     13047.0  United Kingdom
# 11   2,1     13047.0  United Kingdom
# 12  3,75     13047.0  United Kingdom
# 13  1,65     13047.0  United Kingdom
# 14  4,25     13047.0  United Kingdom
# 15  4,95     13047.0  United Kingdom
# 16  9,95     13047.0  United Kingdom
# 17  5,95     13047.0  United Kingdom
# 18  5,95     13047.0  United Kingdom
# 19  7,95     13047.0  United Kingdom

# %% [markdown]
# ### Cleansing Datasets

# %%
data.isnull().sum()
# Out:
# BillNo             0
# Itemname        1455
# Quantity           0
# Date               0
# Price              0
# CustomerID    134041
# Country            0
# dtype: int64

# %%
data = data.dropna(subset=["Itemname"])

# %%
data = data.fillna(0)

# %% [markdown]
# ### Membuat Pivot Table

# %%
basket = data.groupby(["BillNo","Itemname"])["Quantity"].sum().unstack().reset_index().fillna(0).set_index("BillNo")
basket
# Out:
# Itemname  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# BillNo
# 536365                      0.0                      0.0
# 536366                      0.0                      0.0
# 536367                      0.0                      0.0
# 536368                      0.0                      0.0
# 536369                      0.0                      0.0
# ...                         ...                      ...
# 572057                      0.0                      0.0
# 572058                      0.0                      0.0
# A563185                     0.0                      0.0
# A563186                     0.0                      0.0
# A563187                     0.0                      0.0
#
# Itemname  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# BillNo
# 536365                       0.0                         0.0
# 536366                       0.0                         0.0
# 536367                       0.0                         0.0
# 536368                       0.0                         0.0
# 536369                       0.0                         0.0
# ...                          ...                         ...
# 572057                       0.0                         0.0
# 572058                       0.0                         0.0
# A563185                      0.0                         0.0
# A563186                      0.0                         0.0
# A563187                      0.0                         0.0
#
# Itemname  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# BillNo
# 536365                          0.0                        0.0
# 536366                          0.0                        0.0
# 536367                          0.0                        0.0
# 536368                          0.0                        0.0
# 536369                          0.0                        0.0
# ...                             ...                        ...
# 572057                          0.0                        0.0
# 572058                          0.0                        0.0
# A563185                         0.0                        0.0
# A563186                         0.0                        0.0
# A563187                         0.0                        0.0
#
# Itemname  12 HANGING EGGS HAND PAINTED  12 IVORY ROSE PEG PLACE SETTINGS  \
# BillNo
# 536365                             0.0                               0.0
# 536366                             0.0                               0.0
# 536367                             0.0                               0.0
# 536368                             0.0                               0.0
# 536369                             0.0                               0.0
# ...                                ...                               ...
# 572057                             0.0                               0.0
# 572058                             0.0                               0.0
# A563185                            0.0                               0.0
# A563186                            0.0                               0.0
# A563187                            0.0                               0.0
#
# Itemname  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  ...  \
# BillNo                                                                    ...
# 536365                                0.0                            0.0  ...
# 536366                                0.0                            0.0  ...
# 536367                                0.0                            0.0  ...
# 536368                                0.0                            0.0  ...
# 536369                                0.0                            0.0  ...
# ...                                   ...                            ...  ...
# 572057                                0.0                            0.0  ...
# 572058                                0.0                            0.0  ...
# A563185                               0.0                            0.0  ...
# A563186                               0.0                            0.0  ...
# A563187                               0.0                            0.0  ...
#
# Itemname  wrongly coded 20713  wrongly coded 23343  wrongly coded-23343  \
# BillNo
# 536365                    0.0                  0.0                  0.0
# 536366                    0.0                  0.0                  0.0
# 536367                    0.0                  0.0                  0.0
# 536368                    0.0                  0.0                  0.0
# 536369                    0.0                  0.0                  0.0
# ...                       ...                  ...                  ...
# 572057                    0.0                  0.0                  0.0
# 572058                    0.0                  0.0                  0.0
# A563185                   0.0                  0.0                  0.0
# A563186                   0.0                  0.0                  0.0
# A563187                   0.0                  0.0                  0.0
#
# Itemname  wrongly marked  wrongly marked 23343  wrongly marked carton 22804  \
# BillNo
# 536365               0.0                   0.0                          0.0
# 536366               0.0                   0.0                          0.0
# 536367               0.0                   0.0                          0.0
# 536368               0.0                   0.0                          0.0
# 536369               0.0                   0.0                          0.0
# ...                  ...                   ...                          ...
# 572057               0.0                   0.0                          0.0
# 572058               0.0                   0.0                          0.0
# A563185              0.0                   0.0                          0.0
# A563186              0.0                   0.0                          0.0
# A563187              0.0                   0.0                          0.0
#
# Itemname  wrongly marked. 23343 in box  wrongly sold (22719) barcode  \
# BillNo
# 536365                             0.0                           0.0
# 536366                             0.0                           0.0
# 536367                             0.0                           0.0
# 536368                             0.0                           0.0
# 536369                             0.0                           0.0
# ...                                ...                           ...
# 572057                             0.0                           0.0
# 572058                             0.0                           0.0
# A563185                            0.0                           0.0
# A563186                            0.0                           0.0
# A563187                            0.0                           0.0
#
# Itemname  wrongly sold as sets  wrongly sold sets
# BillNo
# 536365                     0.0                0.0
# 536366                     0.0                0.0
# 536367                     0.0                0.0
# 536368                     0.0                0.0
# 536369                     0.0                0.0
# ...                        ...                ...
# 572057                     0.0                0.0
# 572058                     0.0                0.0
# A563185                    0.0                0.0
# A563186                    0.0                0.0
# A563187                    0.0                0.0
#
# [20210 rows x 4185 columns]

# %% [markdown]
# ### Mengubah data kuantitas menjadi 1 / 0

# %%
#mengubah dari 0,0 menjadi 0
def one_hot_encoding(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1
basket = basket.applymap(one_hot_encoding)
basket
# Out:
# Itemname  *Boombox Ipod Classic  *USB Office Mirror Ball  \
# BillNo
# 536365                        0                        0
# 536366                        0                        0
# 536367                        0                        0
# 536368                        0                        0
# 536369                        0                        0
# ...                         ...                      ...
# 572057                        0                        0
# 572058                        0                        0
# A563185                       0                        0
# A563186                       0                        0
# A563187                       0                        0
#
# Itemname  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# BillNo
# 536365                         0                           0
# 536366                         0                           0
# 536367                         0                           0
# 536368                         0                           0
# 536369                         0                           0
# ...                          ...                         ...
# 572057                         0                           0
# 572058                         0                           0
# A563185                        0                           0
# A563186                        0                           0
# A563187                        0                           0
#
# Itemname  12 DAISY PEGS IN WOOD BOX  12 EGG HOUSE PAINTED WOOD  \
# BillNo
# 536365                            0                          0
# 536366                            0                          0
# 536367                            0                          0
# 536368                            0                          0
# 536369                            0                          0
# ...                             ...                        ...
# 572057                            0                          0
# 572058                            0                          0
# A563185                           0                          0
# A563186                           0                          0
# A563187                           0                          0
#
# Itemname  12 HANGING EGGS HAND PAINTED  12 IVORY ROSE PEG PLACE SETTINGS  \
# BillNo
# 536365                               0                                 0
# 536366                               0                                 0
# 536367                               0                                 0
# 536368                               0                                 0
# 536369                               0                                 0
# ...                                ...                               ...
# 572057                               0                                 0
# 572058                               0                                 0
# A563185                              0                                 0
# A563186                              0                                 0
# A563187                              0                                 0
#
# Itemname  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  ...  \
# BillNo                                                                    ...
# 536365                                  0                              0  ...
# 536366                                  0                              0  ...
# 536367                                  0                              0  ...
# 536368                                  0                              0  ...
# 536369                                  0                              0  ...
# ...                                   ...                            ...  ...
# 572057                                  0                              0  ...
# 572058                                  0                              0  ...
# A563185                                 0                              0  ...
# A563186                                 0                              0  ...
# A563187                                 0                              0  ...
#
# Itemname  wrongly coded 20713  wrongly coded 23343  wrongly coded-23343  \
# BillNo
# 536365                      0                    0                    0
# 536366                      0                    0                    0
# 536367                      0                    0                    0
# 536368                      0                    0                    0
# 536369                      0                    0                    0
# ...                       ...                  ...                  ...
# 572057                      0                    0                    0
# 572058                      0                    0                    0
# A563185                     0                    0                    0
# A563186                     0                    0                    0
# A563187                     0                    0                    0
#
# Itemname  wrongly marked  wrongly marked 23343  wrongly marked carton 22804  \
# BillNo
# 536365                 0                     0                            0
# 536366                 0                     0                            0
# 536367                 0                     0                            0
# 536368                 0                     0                            0
# 536369                 0                     0                            0
# ...                  ...                   ...                          ...
# 572057                 0                     0                            0
# 572058                 0                     0                            0
# A563185                0                     0                            0
# A563186                0                     0                            0
# A563187                0                     0                            0
#
# Itemname  wrongly marked. 23343 in box  wrongly sold (22719) barcode  \
# BillNo
# 536365                               0                             0
# 536366                               0                             0
# 536367                               0                             0
# 536368                               0                             0
# 536369                               0                             0
# ...                                ...                           ...
# 572057                               0                             0
# 572058                               0                             0
# A563185                              0                             0
# A563186                              0                             0
# A563187                              0                             0
#
# Itemname  wrongly sold as sets  wrongly sold sets
# BillNo
# 536365                       0                  0
# 536366                       0                  0
# 536367                       0                  0
# 536368                       0                  0
# 536369                       0                  0
# ...                        ...                ...
# 572057                       0                  0
# 572058                       0                  0
# A563185                      0                  0
# A563186                      0                  0
# A563187                      0                  0
#
# [20210 rows x 4185 columns]

# %%
freq_items=apriori(basket,min_support=0.02,use_colnames=True)
res1 = association_rules(freq_items,  metric="lift", min_threshold=1)
res1.sort_values("confidence",ascending=False, inplace=True)
res1
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                                            antecedents  \
# 152  (ROSES REGENCY TEACUP AND SAUCER, PINK REGENCY...
# 154  (PINK REGENCY TEACUP AND SAUCER, GREEN REGENCY...
# 24                    (PINK REGENCY TEACUP AND SAUCER)
# 160  (JUMBO STORAGE BAG SUKI, JUMBO BAG PINK POLKADOT)
# 139                   (PINK REGENCY TEACUP AND SAUCER)
# ..                                                 ...
# 70                           (JUMBO BAG RED RETROSPOT)
# 161                          (JUMBO BAG RED RETROSPOT)
# 42                           (JUMBO BAG RED RETROSPOT)
# 130               (WHITE HANGING HEART T-LIGHT HOLDER)
# 148               (WHITE HANGING HEART T-LIGHT HOLDER)
#
#                                            consequents  antecedent support  \
# 152                  (GREEN REGENCY TEACUP AND SAUCER)            0.028204
# 154                  (ROSES REGENCY TEACUP AND SAUCER)            0.029936
# 24                   (GREEN REGENCY TEACUP AND SAUCER)            0.036418
# 160                          (JUMBO BAG RED RETROSPOT)            0.025433
# 139                  (ROSES REGENCY TEACUP AND SAUCER)            0.036418
# ..                                                 ...                 ...
# 70                          (JUMBO STORAGE BAG SKULLS)            0.102128
# 161  (JUMBO STORAGE BAG SUKI, JUMBO BAG PINK POLKADOT)            0.102128
# 42                                (JUMBO BAG ALPHABET)            0.102128
# 130                   (NATURAL SLATE HEART CHALKBOARD)            0.108956
# 148                (WOODEN PICTURE FRAME WHITE FINISH)            0.108956
#
#      consequent support   support  confidence       lift  leverage  conviction
# 152            0.048243  0.025482    0.903509  18.728115  0.024122    9.863659
# 154            0.050124  0.025482    0.851240  16.982778  0.023982    6.385280
# 24             0.048243  0.029936    0.822011  17.038810  0.028179    5.347273
# 160            0.102128  0.020386    0.801556   7.848573  0.017789    4.524572
# 139            0.050124  0.028204    0.774457  15.450905  0.026378    4.211500
# ..                  ...       ...         ...        ...       ...         ...
# 70             0.034785  0.020435    0.200097   5.752430  0.016883    1.206665
# 161            0.025433  0.020386    0.199612   7.848573  0.017789    1.217619
# 42             0.043790  0.020336    0.199128   4.547316  0.015864    1.193961
# 130            0.060960  0.020336    0.186649   3.061823  0.013695    1.154532
# 148            0.054033  0.020040    0.183924   3.403936  0.014152    1.159165
#
# [164 rows x 9 columns]

# %% [markdown]
# ### Mencari Frequent Itemsets dengan Apriori dan FPGrowth

# %% [markdown]
# #### Frequent Itemsets dengan Apriori

# %%
freq_items=apriori(basket,min_support=0.02,use_colnames=True)
res1 = association_rules(freq_items,  metric="lift", min_threshold=1)
res1
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                                            antecedents  \
# 0                        (60 TEATIME FAIRY CAKE CASES)
# 1                    (PACK OF 72 RETROSPOT CAKE CASES)
# 2                         (ALARM CLOCK BAKELIKE GREEN)
# 3                          (ALARM CLOCK BAKELIKE PINK)
# 4                         (ALARM CLOCK BAKELIKE GREEN)
# ..                                                 ...
# 159  (JUMBO BAG RED RETROSPOT, JUMBO BAG PINK POLKA...
# 160  (JUMBO STORAGE BAG SUKI, JUMBO BAG PINK POLKADOT)
# 161                          (JUMBO BAG RED RETROSPOT)
# 162                           (JUMBO STORAGE BAG SUKI)
# 163                          (JUMBO BAG PINK POLKADOT)
#
#                                            consequents  antecedent support  \
# 0                    (PACK OF 72 RETROSPOT CAKE CASES)            0.039485
# 1                        (60 TEATIME FAIRY CAKE CASES)            0.063286
# 2                          (ALARM CLOCK BAKELIKE PINK)            0.047848
# 3                         (ALARM CLOCK BAKELIKE GREEN)            0.037556
# 4                           (ALARM CLOCK BAKELIKE RED)            0.047848
# ..                                                 ...                 ...
# 159                           (JUMBO STORAGE BAG SUKI)            0.040524
# 160                          (JUMBO BAG RED RETROSPOT)            0.025433
# 161  (JUMBO STORAGE BAG SUKI, JUMBO BAG PINK POLKADOT)            0.102128
# 162  (JUMBO BAG RED RETROSPOT, JUMBO BAG PINK POLKA...            0.058288
# 163  (JUMBO BAG RED RETROSPOT, JUMBO STORAGE BAG SUKI)            0.059921
#
#      consequent support   support  confidence       lift  leverage  conviction
# 0              0.063286  0.021524    0.545113   8.613549  0.019025    2.059224
# 1              0.039485  0.021524    0.340109   8.613549  0.019025    1.455567
# 2              0.037556  0.020336    0.425026  11.317223  0.018540    1.673891
# 3              0.047848  0.020336    0.541502  11.317223  0.018540    2.076677
# 4              0.050816  0.031321    0.654602  12.881698  0.028890    2.748085
# ..                  ...       ...         ...        ...       ...         ...
# 159            0.058288  0.020386    0.503053   8.630468  0.018024    1.894993
# 160            0.102128  0.020386    0.801556   7.848573  0.017789    4.524572
# 161            0.025433  0.020386    0.199612   7.848573  0.017789    1.217619
# 162            0.040524  0.020386    0.349745   8.630468  0.018024    1.475538
# 163            0.035675  0.020386    0.340215   9.536393  0.018248    1.461573
#
# [164 rows x 9 columns]

# %%
freq_items=apriori(basket,min_support=0.03,use_colnames=True)
res1 = association_rules(freq_items,  metric="lift", min_threshold=1)
res1
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                             antecedents                          consequents  \
# 0          (ALARM CLOCK BAKELIKE GREEN)           (ALARM CLOCK BAKELIKE RED)
# 1            (ALARM CLOCK BAKELIKE RED)         (ALARM CLOCK BAKELIKE GREEN)
# 2     (ROSES REGENCY TEACUP AND SAUCER)    (GREEN REGENCY TEACUP AND SAUCER)
# 3     (GREEN REGENCY TEACUP AND SAUCER)    (ROSES REGENCY TEACUP AND SAUCER)
# 4             (JUMBO BAG RED RETROSPOT)            (JUMBO BAG PINK POLKADOT)
# 5             (JUMBO BAG PINK POLKADOT)            (JUMBO BAG RED RETROSPOT)
# 6             (JUMBO BAG RED RETROSPOT)  (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 7   (JUMBO SHOPPER VINTAGE RED PAISLEY)            (JUMBO BAG RED RETROSPOT)
# 8             (JUMBO BAG RED RETROSPOT)             (JUMBO STORAGE BAG SUKI)
# 9              (JUMBO STORAGE BAG SUKI)            (JUMBO BAG RED RETROSPOT)
# 10            (LUNCH BAG RED RETROSPOT)            (LUNCH BAG  BLACK SKULL.)
# 11            (LUNCH BAG  BLACK SKULL.)            (LUNCH BAG RED RETROSPOT)
#
#     antecedent support  consequent support   support  confidence       lift  \
# 0             0.047848            0.050816  0.031321    0.654602  12.881698
# 1             0.050816            0.047848  0.031321    0.616358  12.881698
# 2             0.050124            0.048243  0.036170    0.721619  14.957866
# 3             0.048243            0.050124  0.036170    0.749744  14.957866
# 4             0.102128            0.059921  0.040524    0.396802   6.622110
# 5             0.059921            0.102128  0.040524    0.676301   6.622110
# 6             0.102128            0.057694  0.033449    0.327519   5.676815
# 7             0.057694            0.102128  0.033449    0.579760   5.676815
# 8             0.102128            0.058288  0.035675    0.349322   5.993032
# 9             0.058288            0.102128  0.035675    0.612054   5.993032
# 10            0.076249            0.062345  0.031272    0.410123   6.578247
# 11            0.062345            0.076249  0.031272    0.501587   6.578247
#
#     leverage  conviction
# 0   0.028890    2.748085
# 1   0.028890    2.481879
# 2   0.033752    3.418899
# 3   0.033752    3.795612
# 4   0.034405    1.558493
# 5   0.034405    2.773784
# 6   0.027557    1.401239
# 7   0.027557    2.136570
# 8   0.029723    1.447277
# 9   0.029723    2.314428
# 10  0.026518    1.589577
# 11  0.026518    1.853385

# %%
freq_items=apriori(basket,min_support=0.04,use_colnames=True)
res1 = association_rules(freq_items,  metric="lift", min_threshold=1)
res1
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                  antecedents                consequents  antecedent support  \
# 0  (JUMBO BAG RED RETROSPOT)  (JUMBO BAG PINK POLKADOT)            0.102128
# 1  (JUMBO BAG PINK POLKADOT)  (JUMBO BAG RED RETROSPOT)            0.059921
#
#    consequent support   support  confidence     lift  leverage  conviction
# 0            0.059921  0.040524    0.396802  6.62211  0.034405    1.558493
# 1            0.102128  0.040524    0.676301  6.62211  0.034405    2.773784

# %%
freq_items=apriori(basket,min_support=0.015,use_colnames=True)
res1 = association_rules(freq_items,  metric="lift", min_threshold=1)
res1
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                                            antecedents  \
# 0                        (60 TEATIME FAIRY CAKE CASES)
# 1                 (PACK OF 60 PINK PAISLEY CAKE CASES)
# 2                        (60 TEATIME FAIRY CAKE CASES)
# 3                    (PACK OF 72 RETROSPOT CAKE CASES)
# 4                         (ALARM CLOCK BAKELIKE IVORY)
# ..                                                 ...
# 519  (WOODLAND CHARLOTTE BAG, RED RETROSPOT CHARLOT...
# 520  (STRAWBERRY CHARLOTTE BAG, RED RETROSPOT CHARL...
# 521                           (WOODLAND CHARLOTTE BAG)
# 522                         (STRAWBERRY CHARLOTTE BAG)
# 523                      (RED RETROSPOT CHARLOTTE BAG)
#
#                                            consequents  antecedent support  \
# 0                 (PACK OF 60 PINK PAISLEY CAKE CASES)            0.039485
# 1                        (60 TEATIME FAIRY CAKE CASES)            0.041613
# 2                    (PACK OF 72 RETROSPOT CAKE CASES)            0.039485
# 3                        (60 TEATIME FAIRY CAKE CASES)            0.063286
# 4                         (ALARM CLOCK BAKELIKE GREEN)            0.027759
# ..                                                 ...                 ...
# 519                         (STRAWBERRY CHARLOTTE BAG)            0.024889
# 520                           (WOODLAND CHARLOTTE BAG)            0.023850
# 521  (STRAWBERRY CHARLOTTE BAG, RED RETROSPOT CHARL...            0.040920
# 522  (WOODLAND CHARLOTTE BAG, RED RETROSPOT CHARLOT...            0.035428
# 523  (WOODLAND CHARLOTTE BAG, STRAWBERRY CHARLOTTE ...            0.050866
#
#      consequent support   support  confidence       lift  leverage  conviction
# 0              0.041613  0.016724    0.423559  10.178508  0.015081    1.662593
# 1              0.039485  0.016724    0.401902  10.178508  0.015081    1.605950
# 2              0.063286  0.021524    0.545113   8.613549  0.019025    2.059224
# 3              0.039485  0.021524    0.340109   8.613549  0.019025    1.455567
# 4              0.047848  0.016329    0.588235  12.293935  0.015000    2.312370
# ..                  ...       ...         ...        ...       ...         ...
# 519            0.035428  0.016081    0.646123  18.237641  0.015199    2.725729
# 520            0.040920  0.016081    0.674274  16.477720  0.015105    2.944436
# 521            0.023850  0.016081    0.392987  16.477720  0.015105    1.608120
# 522            0.024889  0.016081    0.453911  18.237641  0.015199    1.785626
# 523            0.019990  0.016081    0.316148  15.815218  0.015064    1.433073
#
# [524 rows x 9 columns]

# %% [markdown]
# #### Frequent Itemsets dengan FPGrowth

# %%
#running the fpgrowth algorithm
res=fpgrowth(basket,min_support=0.02,use_colnames=True)
res2 = association_rules(res,  metric="lift", min_threshold=1)
res2
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                              antecedents                          consequents  \
# 0               (JAM MAKING SET PRINTED)           (JAM MAKING SET WITH JARS)
# 1             (JAM MAKING SET WITH JARS)             (JAM MAKING SET PRINTED)
# 2           (ALARM CLOCK BAKELIKE GREEN)           (ALARM CLOCK BAKELIKE RED)
# 3             (ALARM CLOCK BAKELIKE RED)         (ALARM CLOCK BAKELIKE GREEN)
# 4             (ALARM CLOCK BAKELIKE RED)          (ALARM CLOCK BAKELIKE PINK)
# ..                                   ...                                  ...
# 159                     (SPOTTY BUNTING)                      (PARTY BUNTING)
# 160             (JUMBO BAG VINTAGE LEAF)            (JUMBO BAG RED RETROSPOT)
# 161            (JUMBO BAG RED RETROSPOT)             (JUMBO BAG VINTAGE LEAF)
# 162  (GARDENERS KNEELING PAD CUP OF TEA)   (GARDENERS KNEELING PAD KEEP CALM)
# 163   (GARDENERS KNEELING PAD KEEP CALM)  (GARDENERS KNEELING PAD CUP OF TEA)
#
#      antecedent support  consequent support   support  confidence       lift  \
# 0              0.055220            0.053884  0.022365    0.405018   7.516448
# 1              0.053884            0.055220  0.022365    0.415060   7.516448
# 2              0.047848            0.050816  0.031321    0.654602  12.881698
# 3              0.050816            0.047848  0.031321    0.616358  12.881698
# 4              0.050816            0.037556  0.022464    0.442064  11.770908
# ..                  ...                 ...       ...         ...        ...
# 159            0.055121            0.081940  0.023404    0.424596   5.181815
# 160            0.042454            0.102128  0.020782    0.489510   4.793124
# 161            0.102128            0.042454  0.020782    0.203488   4.793124
# 162            0.037308            0.044780  0.026917    0.721485  16.111845
# 163            0.044780            0.037308  0.026917    0.601105  16.111845
#
#      leverage  conviction
# 0    0.019390    1.590158
# 1    0.019390    1.615173
# 2    0.028890    2.748085
# 3    0.028890    2.481879
# 4    0.020556    1.725009
# ..        ...         ...
# 159  0.018888    1.595506
# 160  0.016446    1.758846
# 161  0.016446    1.202174
# 162  0.025247    3.429695
# 163  0.025247    2.413396
#
# [164 rows x 9 columns]

# %%
res=fpgrowth(basket,min_support=0.03,use_colnames=True)
res2 = association_rules(res,  metric="lift", min_threshold=1)
res2
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                             antecedents                          consequents  \
# 0          (ALARM CLOCK BAKELIKE GREEN)           (ALARM CLOCK BAKELIKE RED)
# 1            (ALARM CLOCK BAKELIKE RED)         (ALARM CLOCK BAKELIKE GREEN)
# 2             (JUMBO BAG RED RETROSPOT)            (JUMBO BAG PINK POLKADOT)
# 3             (JUMBO BAG PINK POLKADOT)            (JUMBO BAG RED RETROSPOT)
# 4             (JUMBO BAG RED RETROSPOT)             (JUMBO STORAGE BAG SUKI)
# 5              (JUMBO STORAGE BAG SUKI)            (JUMBO BAG RED RETROSPOT)
# 6             (JUMBO BAG RED RETROSPOT)  (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 7   (JUMBO SHOPPER VINTAGE RED PAISLEY)            (JUMBO BAG RED RETROSPOT)
# 8             (LUNCH BAG RED RETROSPOT)            (LUNCH BAG  BLACK SKULL.)
# 9             (LUNCH BAG  BLACK SKULL.)            (LUNCH BAG RED RETROSPOT)
# 10    (ROSES REGENCY TEACUP AND SAUCER)    (GREEN REGENCY TEACUP AND SAUCER)
# 11    (GREEN REGENCY TEACUP AND SAUCER)    (ROSES REGENCY TEACUP AND SAUCER)
#
#     antecedent support  consequent support   support  confidence       lift  \
# 0             0.047848            0.050816  0.031321    0.654602  12.881698
# 1             0.050816            0.047848  0.031321    0.616358  12.881698
# 2             0.102128            0.059921  0.040524    0.396802   6.622110
# 3             0.059921            0.102128  0.040524    0.676301   6.622110
# 4             0.102128            0.058288  0.035675    0.349322   5.993032
# 5             0.058288            0.102128  0.035675    0.612054   5.993032
# 6             0.102128            0.057694  0.033449    0.327519   5.676815
# 7             0.057694            0.102128  0.033449    0.579760   5.676815
# 8             0.076249            0.062345  0.031272    0.410123   6.578247
# 9             0.062345            0.076249  0.031272    0.501587   6.578247
# 10            0.050124            0.048243  0.036170    0.721619  14.957866
# 11            0.048243            0.050124  0.036170    0.749744  14.957866
#
#     leverage  conviction
# 0   0.028890    2.748085
# 1   0.028890    2.481879
# 2   0.034405    1.558493
# 3   0.034405    2.773784
# 4   0.029723    1.447277
# 5   0.029723    2.314428
# 6   0.027557    1.401239
# 7   0.027557    2.136570
# 8   0.026518    1.589577
# 9   0.026518    1.853385
# 10  0.033752    3.418899
# 11  0.033752    3.795612

# %%
res=fpgrowth(basket,min_support=0.04,use_colnames=True)
res2 = association_rules(res,  metric="lift", min_threshold=1)
res2
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                  antecedents                consequents  antecedent support  \
# 0  (JUMBO BAG RED RETROSPOT)  (JUMBO BAG PINK POLKADOT)            0.102128
# 1  (JUMBO BAG PINK POLKADOT)  (JUMBO BAG RED RETROSPOT)            0.059921
#
#    consequent support   support  confidence     lift  leverage  conviction
# 0            0.059921  0.040524    0.396802  6.62211  0.034405    1.558493
# 1            0.102128  0.040524    0.676301  6.62211  0.034405    2.773784

# %%
res=fpgrowth(basket,min_support=0.015,use_colnames=True)
res2 = association_rules(res,  metric="lift", min_threshold=1)
res2
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#                               antecedents  \
# 0    (WHITE HANGING HEART T-LIGHT HOLDER)
# 1         (ASSORTED COLOUR BIRD ORNAMENT)
# 2             (POPPY'S PLAYHOUSE BEDROOM)
# 3             (POPPY'S PLAYHOUSE KITCHEN)
# 4                (JAM MAKING SET PRINTED)
# ..                                    ...
# 519    (GARDENERS KNEELING PAD KEEP CALM)
# 520            (JUMBO BAG 50'S CHRISTMAS)
# 521         (JUMBO BAG VINTAGE CHRISTMAS)
# 522             (JUMBO BAG RED RETROSPOT)
# 523             (JUMBO BAG VINTAGE DOILY)
#
#                               consequents  antecedent support  \
# 0         (ASSORTED COLOUR BIRD ORNAMENT)            0.108956
# 1    (WHITE HANGING HEART T-LIGHT HOLDER)            0.070807
# 2             (POPPY'S PLAYHOUSE KITCHEN)            0.020435
# 3             (POPPY'S PLAYHOUSE BEDROOM)            0.021029
# 4              (JAM MAKING SET WITH JARS)            0.055220
# ..                                    ...                 ...
# 519   (GARDENERS KNEELING PAD CUP OF TEA)            0.044780
# 520         (JUMBO BAG VINTAGE CHRISTMAS)            0.035082
# 521            (JUMBO BAG 50'S CHRISTMAS)            0.023256
# 522             (JUMBO BAG VINTAGE DOILY)            0.102128
# 523             (JUMBO BAG RED RETROSPOT)            0.034488
#
#      consequent support   support  confidence       lift  leverage  conviction
# 0              0.070807  0.015438    0.141689   2.001078  0.007723    1.082584
# 1              0.108956  0.015438    0.218029   2.001078  0.007723    1.139485
# 2              0.021029  0.015042    0.736077  35.002649  0.014612    3.709311
# 3              0.020435  0.015042    0.715294  35.002649  0.014612    3.440619
# 4              0.053884  0.022365    0.405018   7.516448  0.019390    1.590158
# ..                  ...       ...         ...        ...       ...         ...
# 519            0.037308  0.026917    0.601105  16.111845  0.025247    2.413396
# 520            0.023256  0.015784    0.449929  19.346968  0.014968    1.775671
# 521            0.035082  0.015784    0.678723  19.346968  0.014968    3.003388
# 522            0.034488  0.017318    0.169574   4.916906  0.013796    1.162670
# 523            0.102128  0.017318    0.502152   4.916906  0.013796    1.803507
#
# [524 rows x 9 columns]

# %% [markdown]
# ### Testing performance - Mencari perbedaan waktu eksekusi

# %% [markdown]
# #### Support = 0.015

# %%
start_time = time.time()

# Generate frequent itemsets and rules
res=fpgrowth(basket,min_support=0.015,use_colnames=True)

# Record end time
end_time = time.time()

# Calculate testing time
testing_time = end_time - start_time
print("Testing time: {:.2f} seconds".format(testing_time))
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Testing time: 10.16 seconds

# %%
start_time = time.time()

# Generate frequent itemsets and rules
res=apriori(basket,min_support=0.015,use_colnames=True)

# Record end time
end_time = time.time()

# Calculate testing time
testing_time = end_time - start_time
print("Testing time: {:.2f} seconds".format(testing_time))
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Testing time: 336.48 seconds

# %%
start_time = time.time()

# Generate frequent itemsets and rules
freq_items=fpgrowth(basket,min_support=0.04,use_colnames=True)
res1 = association_rules(freq_items,  metric="lift", min_threshold=1)

# Record end time
end_time = time.time()

# Calculate testing time
testing_time = end_time - start_time
print("Testing time: {:.2f} seconds".format(testing_time))
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Testing time: 5.13 seconds

# %% [markdown]
# #### Support = 0.02

# %%
start_time = time.time()

# Generate frequent itemsets and rules
freq_items=fpgrowth(basket,min_support=0.02,use_colnames=True)
res1 = association_rules(freq_items,  metric="lift", min_threshold=1)

# Record end time
end_time = time.time()

# Calculate testing time
testing_time = end_time - start_time
print("Testing time: {:.2f} seconds".format(testing_time))
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Testing time: 8.60 seconds

# %%
start_time = time.time()

# Generate frequent itemsets and rules
freq_items=apriori(basket,min_support=0.02,use_colnames=True)
res1 = association_rules(freq_items,  metric="lift", min_threshold=1)

# Record end time
end_time = time.time()

# Calculate testing time
testing_time = end_time - start_time
print("Testing time: {:.2f} seconds".format(testing_time))
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Testing time: 14.10 seconds

# %% [markdown]
# #### Support = 0.03

# %%
start_time = time.time()

# Generate frequent itemsets and rules
freq_items=fpgrowth(basket,min_support=0.03,use_colnames=True)
res1 = association_rules(freq_items,  metric="lift", min_threshold=1)

# Record end time
end_time = time.time()

# Calculate testing time
testing_time = end_time - start_time
print("Testing time: {:.2f} seconds".format(testing_time))
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Testing time: 6.11 seconds

# %%
start_time = time.time()

# Generate frequent itemsets and rules
freq_items=apriori(basket,min_support=0.03,use_colnames=True)
res1 = association_rules(freq_items,  metric="lift", min_threshold=1)

# Record end time
end_time = time.time()

# Calculate testing time
testing_time = end_time - start_time
print("Testing time: {:.2f} seconds".format(testing_time))
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Testing time: 3.03 seconds

# %% [markdown]
# #### Support = 0.04

# %%
start_time = time.time()

# Generate frequent itemsets and rules
freq_items=fpgrowth(basket,min_support=0.04,use_colnames=True)
res1 = association_rules(freq_items,  metric="lift", min_threshold=1)

# Record end time
end_time = time.time()

# Calculate testing time
testing_time = end_time - start_time
print("Testing time: {:.2f} seconds".format(testing_time))
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Testing time: 5.99 seconds

# %%
start_time = time.time()

# Generate frequent itemsets and rules
freq_items=apriori(basket,min_support=0.04,use_colnames=True)
res1 = association_rules(freq_items,  metric="lift", min_threshold=1)

# Record end time
end_time = time.time()

# Calculate testing time
testing_time = end_time - start_time
print("Testing time: {:.2f} seconds".format(testing_time))
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Testing time: 2.09 seconds

# %%
import time
l=[0.015,0.02,0.03,0.04]
t=[]
for i in l:
    t1=time.time()
    apriori(basket,min_support=i,use_colnames=True)
    t2=time.time()
    t.append((t2-t1))
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
t_2=[]
for i in l:
    t1=time.time()
    fpgrowth(basket,min_support=i,use_colnames=True)
    t2=time.time()
    t_2.append((t2-t1))
# Out:
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# c:\Users\Budi\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
sns.lineplot(x=l,y=t_2,label="fpgrowth")
sns.lineplot(x=l,y=t,label="apriori")
plt.xlabel("Min_support Threshold")
plt.ylabel("Run Time in second")
# Out:
# Text(0, 0.5, 'Run Time in second')
